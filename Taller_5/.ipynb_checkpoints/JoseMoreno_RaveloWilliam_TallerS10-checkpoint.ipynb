# %% [markdown]
# <a href="https://colab.research.google.com/github/hectormelo/Machine-Learning-Techniques/blob/main/Taller_5/Taller_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/hectormelo/Machine-Learning-Techniques/main/Banner.png" ><br>
# # Machine Learning Techniques - MISIS4219
#
# Primer semestre - 2024

# %% [markdown]
# ## Taller 5
#
# Este taller consta de un punto, el cual se desarrollara implementando todo lo que hemos visto en esta y las anteriores clases.
#
# **Integrante 1:** Jose Manuel Moreno - 201011998
#
# **Integrante 2:** William Ravelo - 201532093
#
#
# **NOTA:** El archivo .pynb entregado debe tener todas las celdas ejecutadas, con los resultados visibles. El nombre del archivo debe ser NombreApellido1_NombreApellido2_TallerS10.ipynb
#
# **Dataset** : Enlace para descargar el dataset: https://drive.google.com/file/d/1C4zZPQcRY52UzgM8z-gzm4dVtSpSaDmw/view?usp=sharing
#
# **Objetivo**: Contruir modelos de deep learning que ayude a clasificar una imagen en alguna de esas 8 clases del dataset (cada folder en el dataset es una categoría). Va a comparar el performance entre una arquitectura densa y Convnets.

# %% [markdown]
# ## Helpers

# %%
import os
import pandas as pd
import cv2
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import reuters
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation, MaxPooling2D, Conv2D, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib.image as img
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.utils import shuffle

from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, make_scorer

# %%
IMG_SIZE =244

def preprocessig_data(data):
    X = []
    for img_path in data:
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)#Pasamos la imagen a escala de grises
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))/255.0 # normalizamos los pixeles de la imagen

        X.append(img)

    X = np.array(X)
    X = X.reshape((-1, IMG_SIZE, IMG_SIZE, 1)) #Hacemos un reshape de las imagenes

    return X

# %% [markdown]
# ## Carga de datos

# %%
images_path = './natural_images'

# %%
# Ejemplo imagenes
plt.figure(figsize=(20,20))

plt.subplot(1, 3, 1)
plt.title('Airplane')
plt.imshow(cv2.imread(f'{images_path}/airplane/airplane_0000.jpg'))

plt.subplot(1, 3, 2)
plt.title('Car')
plt.imshow(cv2.imread(f'{images_path}/car/car_0000.jpg'))

plt.subplot(1, 3, 3)
plt.title('Cat')
plt.imshow(cv2.imread(f'{images_path}/cat/cat_0000.jpg'))

plt.subplot(2, 3, 1)
plt.title('Dog')
plt.imshow(cv2.imread(f'{images_path}/dog/dog_0000.jpg'))

plt.subplot(2, 3, 2)
plt.title('Flower')
plt.imshow(cv2.imread(f'{images_path}/flower/flower_0000.jpg'))

plt.subplot(2, 3, 3)
plt.title('Fruit')
plt.imshow(cv2.imread(f'{images_path}/fruit/fruit_0000.jpg'))

plt.show()

# %%
filepaths=[]
labels=[]
classlist=os.listdir(images_path)
for klass in classlist:
    classpath=os.path.join(images_path,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)

Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print('distribucion de los datos'.center(60,'-'))
print (df['labels'].value_counts())
# Out:
#                            filepaths labels
# 0  ./natural_images/cat/cat_0258.jpg    cat
# 1  ./natural_images/cat/cat_0516.jpg    cat
# 2  ./natural_images/cat/cat_0270.jpg    cat
# 3  ./natural_images/cat/cat_0264.jpg    cat
# 4  ./natural_images/cat/cat_0502.jpg    cat
# -----------------distribucion de los datos------------------
# labels
# fruit        1000
# person        986
# car           968
# cat           885
# flower        843
# motorbike     788
# airplane      727
# dog           702
# Name: count, dtype: int64

# %%
# Manejo desbalance de los datos
fruit_df = shuffle(df.loc[df['labels'] == 'fruit']).head(702).reset_index(drop=True)
person_df = shuffle(df.loc[df['labels'] == 'person']).head(702).reset_index(drop=True)
car_df = shuffle(df.loc[df['labels'] == 'car']).head(702).reset_index(drop=True)
cat_df = shuffle(df.loc[df['labels'] == 'cat']).head(702).reset_index(drop=True)
flower_df = shuffle(df.loc[df['labels'] == 'flower']).head(702).reset_index(drop=True)
motorbike_df = shuffle(df.loc[df['labels'] == 'motorbike']).head(702).reset_index(drop=True)
airplane_df = shuffle(df.loc[df['labels'] == 'airplane']).head(702).reset_index(drop=True)
dog_df = shuffle(df.loc[df['labels'] == 'dog']).head(702).reset_index(drop=True)

print(fruit_df.shape, person_df.shape, car_df.shape, cat_df.shape, flower_df.shape, motorbike_df.shape, airplane_df.shape, dog_df.shape)
# Out:
# (702, 2) (702, 2) (702, 2) (702, 2) (702, 2) (702, 2) (702, 2) (702, 2)

# %%
balanced_df = pd.concat([fruit_df, person_df, car_df, cat_df, flower_df, motorbike_df, airplane_df, dog_df], ignore_index=True)
balanced_df = shuffle(balanced_df).reset_index(drop = True)
balanced_df.head()
# Out:
#                                        filepaths     labels
# 0        ./natural_images/flower/flower_0586.jpg     flower
# 1        ./natural_images/flower/flower_0488.jpg     flower
# 2  ./natural_images/motorbike/motorbike_0093.jpg  motorbike
# 3        ./natural_images/flower/flower_0560.jpg     flower
# 4              ./natural_images/cat/cat_0149.jpg        cat

# %%
X_train, X_test, y_train, y_test = train_test_split(balanced_df['filepaths'], balanced_df['labels'], test_size=0.30, random_state=33)

X_test, X_val, y_test, y_val= train_test_split(X_test, y_test, train_size=0.5, random_state=34)

# %% [markdown]
# ## Preprocesamiento de los datos

# %%
X_train = preprocessig_data(X_train)
X_val = preprocessig_data(X_val)

# %%
le = LabelEncoder()

y_train = le.fit_transform(y_train)
y_val = le.transform(y_val)

y_train = to_categorical(y_train, num_classes=8)
y_val = to_categorical(y_val, num_classes=8)

# %% [markdown]
# ## Punto 1: Clasificación de imágenes con arquitectura densa
#
# Requerimientos básicos:
# - Divida el dataset en particiones de entrenamiento, validación y testing.
# - Proponga una arquitectura de red neuronal densa con al menos 3 capas.
# - Entrene el modelo y genere las curvas de loss vs epoch para los sets de entrenamiento y validación.
# - Hacer deploy del modelo (realizar prediccion sobre una imagen dada fuera del dataset).
# - Evalue el modelo sobre testing y obtenga el reporte de precision, recall  f1-score. Puede utilizar el macro o micro average.

# %%
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=10)

# %%
model_base = tf.keras.models.Sequential([
  Flatten(input_shape =(IMG_SIZE,IMG_SIZE,1)),

  Dense(512, activation='relu'),
  Dropout(0.15),

  Dense(250, activation='relu'),
  Dropout(0.15),

  Dense(8, activation= 'softmax')
])
# Out:
# /Users/willy/opt/anaconda3/envs/new_env/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model_base.compile(
    optimizer='adam',
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
model_base.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_9 (Flatten)             │ (None, 59536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 512)            │    30,482,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 250)            │       128,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 250)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 8)              │         2,008 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,613,202 (116.78 MB)
#  Trainable params: 30,613,202 (116.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_base = model_base.fit(X_train, y_train, validation_data= (X_val, y_val), batch_size=128, epochs = 100, callbacks=[early])
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.2350 - loss: 1.8526 - val_accuracy: 0.2610 - val_loss: 1.7783
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2356 - loss: 1.8324 - val_accuracy: 0.2645 - val_loss: 1.7701
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2477 - loss: 1.8027 - val_accuracy: 0.2622 - val_loss: 1.7694
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.2517 - loss: 1.8084 - val_accuracy: 0.2705 - val_loss: 1.7628
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2500 - loss: 1.8125 - val_accuracy: 0.2681 - val_loss: 1.7564
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2579 - loss: 1.7984 - val_accuracy: 0.2716 - val_loss: 1.7742
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2668 - loss: 1.7644 - val_accuracy: 0.2764 - val_loss: 1.7570
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2698 - loss: 1.7614 - val_accuracy: 0.2693 - val_loss: 1.7614
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2707 - loss: 1.7740 - val_accuracy: 0.2527 - val_loss: 1.7503
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.2800 - loss: 1.7581 - val_accuracy: 0.2835 - val_loss: 1.7375
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.3071 - loss: 1.7436 - val_accuracy: 0.2705 - val_loss: 1.7372
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.2859 - loss: 1.7403 - val_accuracy: 0.3179 - val_loss: 1.6877
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.3218 - loss: 1.7066 - val_accuracy: 0.3357 - val_loss: 1.6428
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.3182 - loss: 1.6861 - val_accuracy: 0.3464 - val_loss: 1.6216
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.3371 - loss: 1.6504 - val_accuracy: 0.3321 - val_loss: 1.6165
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.3258 - loss: 1.6761 - val_accuracy: 0.3642 - val_loss: 1.5798
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.3517 - loss: 1.6128 - val_accuracy: 0.4709 - val_loss: 1.4222
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.4349 - loss: 1.5055 - val_accuracy: 0.4757 - val_loss: 1.3835
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.4685 - loss: 1.3856 - val_accuracy: 0.4840 - val_loss: 1.3509
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.4690 - loss: 1.3803 - val_accuracy: 0.4864 - val_loss: 1.3268
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.4604 - loss: 1.3554 - val_accuracy: 0.4709 - val_loss: 1.3283
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.4670 - loss: 1.3406 - val_accuracy: 0.4650 - val_loss: 1.3352
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.4940 - loss: 1.3028 - val_accuracy: 0.4947 - val_loss: 1.2935
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.4645 - loss: 1.3421 - val_accuracy: 0.5065 - val_loss: 1.3342
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.4821 - loss: 1.3429 - val_accuracy: 0.4887 - val_loss: 1.3190
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.4899 - loss: 1.3213 - val_accuracy: 0.4816 - val_loss: 1.3036
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.4908 - loss: 1.3071 - val_accuracy: 0.5231 - val_loss: 1.2527
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5198 - loss: 1.2652 - val_accuracy: 0.5350 - val_loss: 1.2470
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5216 - loss: 1.2638 - val_accuracy: 0.5753 - val_loss: 1.1991
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.5612 - loss: 1.2141 - val_accuracy: 0.5575 - val_loss: 1.1961
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5647 - loss: 1.2017 - val_accuracy: 0.4935 - val_loss: 1.2844
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.4835 - loss: 1.2886 - val_accuracy: 0.5777 - val_loss: 1.1812
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5663 - loss: 1.1957 - val_accuracy: 0.5753 - val_loss: 1.1620
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.5449 - loss: 1.2067 - val_accuracy: 0.5872 - val_loss: 1.1209
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5872 - loss: 1.1151 - val_accuracy: 0.5907 - val_loss: 1.1490
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.5736 - loss: 1.1672 - val_accuracy: 0.5480 - val_loss: 1.2174
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5732 - loss: 1.1406 - val_accuracy: 0.6038 - val_loss: 1.0974
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6202 - loss: 1.0703 - val_accuracy: 0.6133 - val_loss: 1.0760
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.5958 - loss: 1.0942 - val_accuracy: 0.6216 - val_loss: 1.0938
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.6132 - loss: 1.0710 - val_accuracy: 0.6002 - val_loss: 1.1072
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5968 - loss: 1.1142 - val_accuracy: 0.6014 - val_loss: 1.0883
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.6206 - loss: 1.0373 - val_accuracy: 0.6251 - val_loss: 1.0811
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.6356 - loss: 1.0034 - val_accuracy: 0.6038 - val_loss: 1.0878
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6343 - loss: 1.0030 - val_accuracy: 0.6204 - val_loss: 1.0836
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6289 - loss: 1.0177 - val_accuracy: 0.6311 - val_loss: 1.0602
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6261 - loss: 1.0473 - val_accuracy: 0.5991 - val_loss: 1.1052
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6259 - loss: 1.0708 - val_accuracy: 0.5813 - val_loss: 1.1397
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6074 - loss: 1.0652 - val_accuracy: 0.5979 - val_loss: 1.0836
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6440 - loss: 1.0040 - val_accuracy: 0.6192 - val_loss: 1.1135
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6335 - loss: 1.0031 - val_accuracy: 0.6216 - val_loss: 1.0418
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.6703 - loss: 0.9438 - val_accuracy: 0.5789 - val_loss: 1.1904
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.5920 - loss: 1.0973 - val_accuracy: 0.6014 - val_loss: 1.0914
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6088 - loss: 1.0726 - val_accuracy: 0.6299 - val_loss: 1.0512
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6250 - loss: 1.0389 - val_accuracy: 0.6121 - val_loss: 1.0767
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6278 - loss: 1.0052 - val_accuracy: 0.6216 - val_loss: 1.0803
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6412 - loss: 0.9795 - val_accuracy: 0.6323 - val_loss: 1.0617
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.6521 - loss: 0.9543 - val_accuracy: 0.6240 - val_loss: 1.0496
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6612 - loss: 0.9285 - val_accuracy: 0.6192 - val_loss: 1.0776
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.6554 - loss: 0.9560 - val_accuracy: 0.6180 - val_loss: 1.1416
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.6364 - loss: 0.9796 - val_accuracy: 0.6263 - val_loss: 1.0668

# %%
df = pd.DataFrame(history_base.history)
df.plot(y=['loss', 'val_loss'], xlabel='epochs', ylabel='loss')

df = pd.DataFrame(history_base.history)
df.plot(y=['accuracy', 'val_accuracy'], xlabel='epochs', ylabel='accuracy')
# Out:
# <Axes: xlabel='epochs', ylabel='accuracy'>

# %% [markdown]
# ## Punto 2: Clasificación de imágenes con ConvNets
#
# Requerimientos básicos:
# - Contruir una red convolucional de al menos 3 capas convolucionales. Utilice las mismas particiones del punto 1.
# - Guardar el modelo proveniente de la red convolucional.
# - Hacer deploy del modelo (realizar prediccion sobre una imagen dada).
# - De ser necesario realizar estrategias de aumentación de datos

# %% [markdown]
# ## Punto 3: Comparación
#
# Compare los modelos, cual se comporto mejor?, por qué?
